# %% [markdown]
# ############################AFSRNet############################

# %%
import torch
import numpy as np
from utils import *
from model import *
def test_net(device, net, patch, pointID, index, dim_desc=128, sz_batch=500):
    net.eval()
    # 每个patch的ID，这里的size是总共有多少个id
    nb_patch = pointID.size
    nb_loop = int(np.ceil(nb_patch/sz_batch))
    desc = torch.zeros(nb_patch, dim_desc)
    with torch.set_grad_enabled(False):
        for i in range(nb_loop):
            st = i * sz_batch
            en = np.min([(i + 1) * sz_batch, nb_patch])
            en = np.min([(i + 1) * sz_batch, nb_patch])
            batch = patch[st:en].to(device)
            batch1=batch[:,:,8:56,8:56]
            batch2=batch[:,:,16:48,16:48]

            out_desc = net(batch,batch1,batch2)
            out_desc = out_desc.to('cpu')
            desc[st:en] = out_desc
            print(': {} of {}'.format(i, nb_loop), end='\r')


    fpr95 = cal_fpr95(desc, pointID, index)
    return fpr95

# %%
#V1数据集上训练的网络
gpu_id  = 1
checkpoint_path = '/media/human_face_need_test/HyNet/Research/AFSRNet_backbone2/PsPDv1/network/2025-04-29_10:34:34AFSR_PsPDv1Train_sz_64_pt_1024_pat_2_dim_384_margin_1.2_drop_0.3_lr_0.1_SGD_None_aug/net-best.pth'
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")
    sz_patch=64
    dim_desc = 384
    net = MSCNet_backbone2()
    net.to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    # 加载模型权重
    net.load_state_dict(checkpoint)
    net.eval()
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /media/miniconda/envs/python3_9/lib/python3.10/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# ...

# %%
#V2数据集上训练的网络
gpu_id  = 1
checkpoint_path = '/media/human_face_need_test/HyNet/Research/AFSRNet_backbone2/PsPDv2/network/2025-04-29_10:24:41AFSR_PsPDv2Train_sz_64_pt_1024_pat_2_dim_384_margin_1.2_drop_0.3_lr_0.1_SGD_None_aug/net-best.pth'
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")
    sz_patch=64
    dim_desc = 384
    net = MSCNet_backbone2()
    net.to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    # 加载模型权重
    net.load_state_dict(checkpoint)
    net.eval()
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_3710705/2670012391.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %%
#V2数据集上训练的网络
gpu_id  = 1
checkpoint_path = '/media/human_face_need_test/HyNet/Research/AFSRNet_backbone2/PsPDv2/network/2025-04-29_10:24:41AFSR_PsPDv2Train_sz_64_pt_1024_pat_2_dim_384_margin_1.2_drop_0.3_lr_0.1_SGD_None_aug/net-best.pth'
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")
    sz_patch=64
    dim_desc = 384
    net = MSCNet_backbone2()
    net.to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    # 加载模型权重
    net.load_state_dict(checkpoint)
    net.eval()
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_3710705/2670012391.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %%
#V2数据集上训练的网络
gpu_id  = 1
checkpoint_path = '/media/human_face_need_test/HyNet/Research/AFSRNet_backbone2/PsPDv3/network/2025-05-06_08:09:29AFSR_PsPDv3Train_sz_64_pt_1024_pat_2_dim_384_margin_1.2_drop_0.3_lr_0.1_SGD_None_aug/net-best.pth'
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")
    sz_patch=64
    dim_desc = 384
    net = MSCNet_backbone2()
    net.to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    # 加载模型权重
    net.load_state_dict(checkpoint)
    net.eval()
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_3710705/2554448283.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %%
    #V2数据集上训练的网络
gpu_id  = 1
checkpoint_path = '/media/human_face_need_test/HyNet/Research/AFSRNet_dpos/PsPDv4/network/2025-08-02_10:16:14HyNet_PsPDv4Train_lam_dis_0.185_sz_64_pt_1024_pat_2_dim_384_alpha_2_margin_1.2_drop_0.3_lr_0.01_Adam_None_aug/net-best.pth'
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")
    sz_patch=64
    dim_desc = 384
    net = MSCNet_backbone2()
    net.to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    # 加载模型权重
    net.load_state_dict(checkpoint)
    net.eval()
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_3710705/1308096859.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %%
print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# PsPDv1Test的结果是：0.02501

# %%
# Out:
# 无法启动 Kernel。
#
# 由于等待端口使用超时，无法启动内核 "python3_9 (Python 3.9.19)"。
#
# 查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>，了解更多详细信息。

# %% [markdown]
# ####################################################################################

# %% [markdown]
# ############################Hynet############################

# %%
import torch
import numpy as np
from utils import *
from model import *
def test_net(device, net, patch, pointID, index, dim_desc=128, sz_batch=500):
    net.eval()
    # 每个patch的ID，这里的size是总共有多少个id
    nb_patch = pointID.size
    nb_loop = int(np.ceil(nb_patch/sz_batch))
    desc = torch.zeros(nb_patch, dim_desc)
    with torch.set_grad_enabled(False):
        for i in range(nb_loop):
            st = i * sz_batch
            en = np.min([(i + 1) * sz_batch, nb_patch])
            batch = patch[st:en].to(device)
            out_desc = net(batch, mode='eval')
            out_desc = out_desc.to('cpu')
            desc[st:en] = out_desc
            print(': {} of {}'.format(i, nb_loop), end='\r')
    fpr95 = cal_fpr95(desc, pointID, index)
    return fpr95

# %%
#V1数据集上训练的网络
gpu_id  = 1
checkpoint_path = '/media/human_face_need_test/HyNet/Research/Hynet/network/2025-03-27_15:30:24HyNet_PsPDv1Train_sz_32_pt_1024_pat_2_dim_128_alpha_2_margin_1.2_drop_0.3_lr_0.01_Adam_None_aug/net-best.pth'
#checkpoint_path = '/media/human_face_need_test/HyNet/Research/Hynet/PsPDv2/network/2025-04-20_11:51:37HyNet_PsPDv2Train_sz_32_pt_1024_pat_2_dim_128_alpha_2_margin_1.2_drop_0.3_lr_0.01_Adam_None_aug/net-best.pth'
#checkpoint_path = '/media/human_face_need_test/HyNet/Research/Hynet/PsPDv3/network/2025-05-06_08:10:40HyNet_PsPDv3Train_sz_32_pt_1024_pat_2_dim_128_alpha_2_margin_1.2_drop_0.3_lr_0.01_Adam_None_aug/net-best.pth'
#checkpoint_path ='/media/human_face_need_test/HyNet/Research/Hynet/PsPDv4/network/2025-05-16_11:29:54HyNet_PsPDv4Train_sz_32_pt_1024_pat_2_dim_128_alpha_2_margin_1.2_drop_0.3_lr_0.01_Adam_None_aug/net-best.pth'
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")

    sz_patch=32
    dim_desc = 128
    drop_rate = 0.3
    net = HyNet(dim_desc=dim_desc, drop_rate=drop_rate)
    net.to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    # 加载模型权重
    net.load_state_dict(checkpoint)
    net.eval()


    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1334275/2516301441.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %%
#V2数据集上训练的网络
gpu_id  = 1
checkpoint_path = '/media/human_face_need_test/HyNet/Research/Hynet/PsPDv2/network/2025-04-20_11:51:37HyNet_PsPDv2Train_sz_32_pt_1024_pat_2_dim_128_alpha_2_margin_1.2_drop_0.3_lr_0.01_Adam_None_aug/net-best.pth'
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv1','PsPDv2']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")

    sz_patch=32
    dim_desc = 128
    drop_rate = 0.3
    net = HyNet(dim_desc=dim_desc, drop_rate=drop_rate)
    net.to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    # 加载模型权重
    net.load_state_dict(checkpoint)
    net.eval()


    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1509531/2920880213.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %% [markdown]
# ####################################################################################

# %% [markdown]
# ############################SDGMNet############################

# %%
import torch
import numpy as np
from utils import *
from model import *
def test_net(device, net, patch, pointID, index, dim_desc=128, sz_batch=500):
    net.eval()
    # 每个patch的ID，这里的size是总共有多少个id
    nb_patch = pointID.size
    nb_loop = int(np.ceil(nb_patch/sz_batch))
    desc = torch.zeros(nb_patch, dim_desc)
    with torch.set_grad_enabled(False):
        for i in range(nb_loop):
            st = i * sz_batch
            en = np.min([(i + 1) * sz_batch, nb_patch])
            batch = patch[st:en].to(device)
            out_desc = net(batch)
            out_desc = out_desc.to('cpu')
            desc[st:en] = out_desc
            print(': {} of {}'.format(i, nb_loop), end='\r')
    fpr95 = cal_fpr95(desc, pointID, index)
    return fpr95

# %%
#V2数据集上训练的网络
gpu_id  = 1
checkpoint = torch.load('/media/human_face_need_test/SDGMNet-master/data/PsPDv12025-04-09_18:37:17bs_1024_alpha_0.9_pm_0.6__1/models/Model_tr_human_patch_best.pt')
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv1','PsPDv2']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")

    dim_desc = 128
    sz_patch =32
    model = SDGMNet(0.3)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    model.to(device)
    net = model


    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1334275/492911539.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
#V2数据集上训练的网络
gpu_id  = 1
checkpoint = torch.load('/media/human_face_need_test/SDGMNet-master/data/PsPDv22025-04-20_11:47:12bs_1024_alpha_0.9_pm_0.6__1/models/Model_tr_human_patch_best.pt')
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv1','PsPDv2']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")

    dim_desc = 128
    sz_patch =32
    model = SDGMNet(0.3)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    model.to(device)
    net = model


    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1509531/4034472151.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
#V2数据集上训练的网络
gpu_id  = 1
checkpoint = torch.load('/media/human_face_need_test/SDGMNet-master/data/PsPDv22025-04-20_11:47:12bs_1024_alpha_0.9_pm_0.6__1/models/Model_tr_human_patch_best.pt')
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")

    dim_desc = 128
    sz_patch =32
    model = SDGMNet(0.3)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    model.to(device)
    net = model


    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1334275/264332050.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
#V3数据集上训练的网络
gpu_id  = 1
checkpoint = torch.load('/media/human_face_need_test/SDGMNet-master/data/PsPDv32025-05-09_17:48:01bs_1024_alpha_0.9_pm_0.6__1/models/Model_tr_human_patch_best.pt')
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")

    dim_desc = 128
    sz_patch =32
    model = SDGMNet(0.3)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    model.to(device)
    net = model


    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1334275/2930210700.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
#V2数据集上训练的网络
gpu_id  = 1
checkpoint = torch.load('/media/human_face_need_test/SDGMNet-master/data/PsPDv42025-05-16_11:32:39bs_1024_alpha_0.9_pm_0.6__1/models/Model_tr_human_patch_best.pt')
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]
    device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")

    dim_desc = 128
    sz_patch =32
    model = SDGMNet(0.3)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    model.to(device)
    net = model


    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1334275/2060399708.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# ####################################################################################

# %% [markdown]
# #########################################SIFT###########################################

# %%
# 这样测出来的sift有问题，虽然效果也很差
import torch
import numpy as np
from utils import *
from model import *
def test_net_SIFT(device, net, patch, pointID, index, dim_desc=128, sz_batch=500):
    # 每个patch的ID，这里的size是总共有多少个id
    nb_patch = pointID.size
    nb_loop = int(np.ceil(nb_patch/sz_batch))
    desc = torch.zeros(nb_patch, dim_desc)
    with torch.set_grad_enabled(False):
        for i in range(nb_loop):
            st = i * sz_batch
            en = np.min([(i + 1) * sz_batch, nb_patch])
            batch = patch[st:en].to(device)
            batch = batch.to(dtype=torch.uint8)
            batch_cpu = batch.cpu().numpy()
            descriptors_list = []
            for i in range(batch_cpu.shape[0]):
                patch_one = batch_cpu[i]
                
                # 计算SIFT描述子
                keypoints = [cv2.KeyPoint(16, 16, 32)]  # 在patch的中心创建一个关键点
                _, descriptors = net.compute(patch_one[0], keypoints)  # patch[0] 是因为patch的形状是(1, 64, 64)
                
                # 将描述子添加到列表中
                descriptors_list.append(descriptors)

            # 将描述子列表转换为PyTorch张量
            out_desc = torch.tensor(descriptors_list, device=device)
            out_desc = torch.squeeze(out_desc, dim=1)
            out_desc = out_desc.to('cpu')
            desc[st:en] = out_desc
            print(': {} of {}'.format(i, nb_loop), end='\r')
    fpr95 = cal_fpr95(desc, pointID, index)
    return fpr95

# %%
#V2数据集上训练的网络
gpu_id  = 1
device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")
net = cv2.SIFT_create()
dim_desc = 128
version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]

    sz_patch=32
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net_SIFT(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# Test data of PsPDv4Test already exists!
# /tmp/ipykernel_1334275/3035736520.py:30: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   out_desc = torch.tensor(descriptors_list, device=device)
# PsPDv4Test的结果是：0.37611

# %%
####################################################################################

# %%
#######################################cdf-stc#######################################

# %%
import torch
import numpy as np
from utils import *
from model import *
def test_net(device, net, patch, pointID, index, dim_desc=128, sz_batch=500):
    net.eval()
    # 每个patch的ID，这里的size是总共有多少个id
    nb_patch = pointID.size
    nb_loop = int(np.ceil(nb_patch/sz_batch))
    desc = torch.zeros(nb_patch, dim_desc)
    with torch.set_grad_enabled(False):
        for i in range(nb_loop):
            st = i * sz_batch
            en = np.min([(i + 1) * sz_batch, nb_patch])
            batch = patch[st:en].to(device)
            out_desc = net(batch)
            out_desc = out_desc.to('cpu')
            desc[st:en] = out_desc
            print(': {} of {}'.format(i, nb_loop), end='\r')
    fpr95 = cal_fpr95(desc, pointID, index)
    return fpr95

# %%
gpu_id  = 1
device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")
sz_patch=32
dim_desc = 128
drop_rate = 0.3
net = L2Net(dim_desc=dim_desc, drop_rate=drop_rate)
net.to(device) 
checkpoint_path = '/media/human_face_need_test/HyNet/Research/CDF-STC/PsPDv1/network/2025-04-13_11:06:56human_cdf-stc_PsPDv1Train_sz_32_pt_1024_pat_2_dim_128_margin_1_drop_0.1_lr_0.01_SGD_None_aug/net-best.pth'
checkpoint = torch.load(checkpoint_path, map_location=device)
# 加载模型权重
net.load_state_dict(checkpoint)
net.eval()

version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]

    sz_patch=32
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1334275/1010088987.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %%
####################################################################################

# %%
#########################################HardNet#########################################

# %%
import torch
import numpy as np
from utils import *
from model import *
def test_net_hardnet(device, net, patch, pointID, index, dim_desc=128, sz_batch=500):
    net.eval()
    # 每个patch的ID，这里的size是总共有多少个id
    nb_patch = pointID.size
    nb_loop = int(np.ceil(nb_patch/sz_batch))
    desc = torch.zeros(nb_patch, dim_desc)
    with torch.set_grad_enabled(False):
        for i in range(nb_loop):
            st = i * sz_batch
            en = np.min([(i + 1) * sz_batch, nb_patch])
            batch = patch[st:en].to(device)
            out_desc = net(batch)
            out_desc = out_desc.to('cpu')
            desc[st:en] = out_desc
            print(': {} of {}'.format(i, nb_loop), end='\r')
    fpr95 = cal_fpr95(desc, pointID, index)
    return fpr95

# %%
gpu_id  = 1
device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")

sz_patch=32
dim_desc = 128
drop_rate = 0.3
net = L2Net(dim_desc=dim_desc, drop_rate=drop_rate)
net.to(device) 
checkpoint_path = '/media/human_face_need_test/HyNet/Research/Hardnet/PsPDv1/network/2025-04-09_15:00:54hardNet_PsPDv1Train_sz_32_pt_1024_pat_2_dim_128_margin_1.2_drop_0.1_lr_0.01_SGD_None_aug/net-best.pth'
checkpoint = torch.load(checkpoint_path, map_location=device)
# 加载模型权重
net.load_state_dict(checkpoint)
net.eval()

version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]

    sz_patch=32
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net_hardnet(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1334275/1976155288.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %%
####################################################################################

# %%
#########################################RALNet########################################

# %%
import torch
import numpy as np
from utils import *
from RAL_net_cov import get_L2_conv
from model import *
def test_net(device, net, patch, pointID, index, dim_desc=128, sz_batch=500):
    net.eval()
    # 每个patch的ID，这里的size是总共有多少个id
    nb_patch = pointID.size
    nb_loop = int(np.ceil(nb_patch/sz_batch))
    desc = torch.zeros(nb_patch, dim_desc)
    with torch.set_grad_enabled(False):
        for i in range(nb_loop):
            st = i * sz_batch
            en = np.min([(i + 1) * sz_batch, nb_patch])
            batch = patch[st:en].to(device)

            out_desc = net(batch)
            out_desc = out_desc.to('cpu')
            desc[st:en] = out_desc
            print(': {} of {}'.format(i, nb_loop), end='\r')


    fpr95 = cal_fpr95(desc, pointID, index)
    return fpr95

# %%
gpu_id  = 1
device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")


sz_patch=32
dim_desc = 128
drop_rate = 0.3
net = RALnet()
net.to(device) 
checkpoint_path = '/media/human_face_need_test/HyNet/Research/RalNet/PsPDv1/network/2025-04-13_11:43:14RALnet_PsPDv1Train_sz_32_pt_1024_pat_2_dim_128_margin_1.2_drop_0.3_lr_10_SGD_None_aug/net-best.pth'
checkpoint = torch.load(checkpoint_path, map_location=device)
# 加载模型权重
net.load_state_dict(checkpoint)
net.eval()


version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]

    sz_patch=32
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net_hardnet(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1334275/3016688746.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %%
####################################################################################

# %% [markdown]
# #########################################SOSNet########################################

# %%
import torch
import numpy as np
from utils import *
from model import *
def test_net(device, net, patch, pointID, index, dim_desc=128, sz_batch=500):
    net.eval()
    # 每个patch的ID，这里的size是总共有多少个id
    nb_patch = pointID.size
    nb_loop = int(np.ceil(nb_patch/sz_batch))
    desc = torch.zeros(nb_patch, dim_desc)
    with torch.set_grad_enabled(False):
        for i in range(nb_loop):
            st = i * sz_batch
            en = np.min([(i + 1) * sz_batch, nb_patch])
            batch = patch[st:en].to(device)
            out_desc = net(batch)
            out_desc = out_desc.to('cpu')
            desc[st:en] = out_desc
            print(': {} of {}'.format(i, nb_loop), end='\r')
    fpr95 = cal_fpr95(desc, pointID, index)
    return fpr95

# %%
gpu_id  = 1
device = torch.device("cuda:{}".format(gpu_id) if torch.cuda.is_available() else "cpu")
sz_patch=32
dim_desc = 128
drop_rate = 0.3
net = L2Net(dim_desc=dim_desc, drop_rate=drop_rate)
net.to(device) 
checkpoint_path = '/media/human_face_need_test/HyNet/Research/SOSnet/PsPDv1/network/2025-04-09_15:02:31SOSNet_PsPDv1Train_sz_32_pt_1024_pat_2_dim_128_SOSR_KNN_8_margin_1.2_drop_0.1_lr_0.01_Adam_None_aug/net-best.pth'
checkpoint = torch.load(checkpoint_path, map_location=device)
# 加载模型权重
net.load_state_dict(checkpoint)
net.eval()

version = ['PsPDv1','PsPDv2','PsPDv3','PsPDv4']
version = ['PsPDv4']
for i in range(len(version)):
    version_select = i
    txt_name = version[version_select]+'_m50_100000_100000.txt'
    test_name =version[version_select]+'Test'
    data_root = '/media/human_face_need_test/'+version[version_select]

    sz_patch=32
    patch_test, pointID_test, index_test=load_human_for_test(data_root,test_name, sz_patch,txt_name=txt_name)
    patch_test = torch.from_numpy(patch_test)
    patch_test = patch_test.to(torch.float32)
    fpr95_current_test = test_net(device, net, patch_test, pointID_test, index_test, dim_desc)
    print(f'{version[version_select]}Test的结果是：{fpr95_current_test}')
# Out:
# /tmp/ipykernel_1334275/1092382863.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# ...

# %%
####################################################################################
